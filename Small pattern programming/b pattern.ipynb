# %%
for i in range(9):
    for j in range(7):
        if (j==1 and i<7 and i!=6) or (((i==3 and j!=2) or i==6)and j>1 and j<5) or j==6 and i>3 and i<6 or j==0 and i==7:
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#  *
#  *
#  *
#  * **
#  *    *
#  *    *
#   ***
# *
