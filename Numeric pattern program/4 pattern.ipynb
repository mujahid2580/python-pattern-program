# %%
for i in range(8):
    for j in range(9):
        if j==6 or i+j==6 and i<6 or i==5 and j>0:
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#       *
#      **
#     * *
#    *  *
#   *   *
#  ********
#       *
#       *
