# %%
for i in range(10):
    for j in range(7):
        if (i==9) or (i-j==2 and (j<2)) or (i==1 and (j<1)) or (i==0 and (j>1 and j<5)) or j==6 and (i>0 and i<3) or i+j ==9 and (i>2)  :
            print("*",end="")
        else:
            print(end=" ")
    print()
# Out:
#   ***
# *     *
# *     *
#  *    *
#      *
#     *
#    *
#   *
#  *
# *******
